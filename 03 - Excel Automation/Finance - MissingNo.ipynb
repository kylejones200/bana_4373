# %% [markdown]
# # Summary
#
# We often work with datasets that are incomplete. Missing data can lead to inaccurate results.
#
# MissingNo is a library that allows users to visualize the "completeness" of their dataset. After completing this tutorial, you will know:
# * How to use MissingNo to visualize missing values in a dataset.
#
# Let’s get started.
#
# # Tutorial Overview
# This tutorial is divided into 2 parts:
# 1. Identifying missing values
# 2. Options for handling missing data

# %% [markdown]
# # Identifying missing values
#
# Data completeness is key to data integrity but it can be hard to identify if a dataset is complete. The module "MissingNo" makes a simple visualization to see where data is missing, signified in white.

# %%
import pandas as pd
import missingno as msno
# %matplotlib inline

df = pd.read_csv('shell financial data.csv')
msno.matrix(df)

# %% [markdown]
# # Handling missing data
#
# There are two general options for handling missing values: dropping observations with missing data or imputing missing data.
#
# ## Dropping missing values
# If you have a large dataset, then dropping incomplete observations is often the best choice.
#
# ## Imputing missing values
# There are several methods for imputing missing values including missing in missing values with a constant value, the mean or median of the avialable values, or the result of an ML method such as linear discriminate analysis.
#
# Pandas and SciKit-Learn offer methods for imputing missing values.

# %% [markdown]
# # Extensions
#
# This section lists some ideas for extending the tutorial that you may wish to explore.
# * How should you handle missing values?
# * Do you get differnt values depending how how you handlt missing data?
#
# # Further Reading
# This section provides more resources on the topic if you are looking to go deeper.
#
# ## APIs
# * Pandas. https://pandas.pydata.org/pandas-docs/stable/user_guide/missing_data.html
# * SciKit-learn. https://scikit-learn.org/stable/modules/impute.html
#
# # Summary
#
# In this tutorial, you were introduced to the MissingNo library. Specifically, you learned:
# * How to use MissingNo to visualize missing data a DataFrame.
# * Options for handling missing data.
#
# # Next
#
# Use MissingNo as part of your exploratory data analysis for your next project.
